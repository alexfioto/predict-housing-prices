# %% [markdown]
# # Manual Feature Creation and Selection

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, PolynomialFeatures, StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import RFE, SelectKBest, f_regression
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.compose import make_column_transformer
from sklearn.svm import SVR
from sklearn.model_selection import StratifiedShuffleSplit

# %%
training = pd.read_csv('./datasets/clean_training_ames.csv', index_col=0)
test = pd.read_csv('./datasets/clean_test_ames.csv', index_col=0)

# %%
list(training.columns)
# Out:
# ['ms_zoning',
#  'street',
#  'alley',
#  'lot_shape',
#  'land_contour',
#  'utilities',
#  'lot_config',
#  'land_slope',
#  'neighborhood',
#  'condition_1',
#  'condition_2',
#  'bldg_type',
#  'house_style',
#  'roof_style',
#  'roof_matl',
#  'exterior_1st',
#  'exterior_2nd',
#  'mas_vnr_type',
#  'exter_qual',
#  'exter_cond',
#  'foundation',
#  'bsmt_qual',
#  'bsmt_cond',
#  'bsmt_exposure',
#  'bsmtfin_type_1',
#  'bsmtfin_type_2',
#  'heating',
#  'heating_qc',
#  'central_air',
#  'electrical',
#  'kitchen_qual',
#  'functional',
#  'fireplace_qu',
#  'garage_type',
#  'garage_finish',
#  'garage_qual',
#  'garage_cond',
#  'paved_drive',
#  'pool_qc',
#  'fence',
#  'misc_feature',
#  'sale_type',
#  'id',
#  'pid',
#  'ms_subclass',
#  'lot_frontage',
#  'lot_area',
#  'overall_qual',
#  'overall_cond',
#  'year_built',
#  'year_remod/add',
#  'mas_vnr_area',
#  'bsmtfin_sf_1',
#  'bsmtfin_sf_2',
#  'bsmt_unf_sf',
#  'total_bsmt_sf',
#  '1st_flr_sf',
#  '2nd_flr_sf',
# ...

# %%
training['total_bath'] = training['bsmt_full_bath'] + \
                         0.5 * training['bsmt_half_bath'] + \
                         training['full_bath'] + \
                         0.5 * training['half_bath']

test['total_bath'] = test['bsmt_full_bath'] + \
                         0.5 * test['bsmt_half_bath'] + \
                         training['full_bath'] + \
                         0.5 * test['half_bath']

# %%
training['exter_qual'] = training['exter_qual'].replace({
    'Po': 1,
    'Fa': 2,
    'TA': 3,
    'Gd': 4,
    'Ex': 5
})

test['exter_qual'] = test['exter_qual'].replace({
    'Po': 1,
    'Fa': 2,
    'TA': 3,
    'Gd': 4,
    'Ex': 5
})

# %%
training['kitchen_qual'] = training['kitchen_qual'].replace({
    'Po': 1,
    'Fa': 2,
    'TA': 3,
    'Gd': 4,
    'Ex': 5
})

test['kitchen_qual'] = test['kitchen_qual'].replace({
    'Po': 1,
    'Fa': 2,
    'TA': 3,
    'Gd': 4,
    'Ex': 5
})

# %%
training['all_sf'] = training['gr_liv_area'] + training['total_bsmt_sf']
training['all_flr_sf'] = training['1st_flr_sf'] + training['2nd_flr_sf']

test['all_sf'] = test['gr_liv_area'] + test['total_bsmt_sf']
test['all_flr_sf'] = test['1st_flr_sf'] + test['2nd_flr_sf']

# %%
training['pool'] = training['pool_qc'].apply(lambda x: 0 if x == 'none' else 1)

# %%
training['garage_ratio'] = training['garage_cars'] / training['garage_area']

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(training.corr()[['saleprice']].sort_values(by='saleprice', ascending=False).head(20), annot=True);

# %%
features = ['overall_qual', 
            'all_sf', 
            'exter_qual', 
            'all_flr_sf', 
            'gr_liv_area', 
            'kitchen_qual', 
            'garage_area',
            'garage_cars',
            'total_bath', 
            'total_bsmt_sf', 
            '1st_flr_sf',
            'year_built',
            'year_remod/add',
            'full_bath',
            'mas_vnr_area',
            'totrms_abvgrd',
            'fireplaces', 
            'bsmtfin_sf_1'
]

# %% [markdown]
# ## Additional EDA

# %%
plt.scatter(training['all_sf'], training['saleprice']);

# %%
training = training[training['all_sf']<6000]

# %%
plt.scatter(training['overall_qual'], training['saleprice']);

# %%
training[(training['overall_qual'] == 9)  & (training['saleprice']<200000)]
training.drop(125, inplace=True)

# %%
training[(training['overall_qual'] == 8)  & (training['saleprice']>500000)]
training.drop(823, inplace=True)

# %%
training[(training['overall_qual'] == 6)  & (training['saleprice']>300000)]
training.drop(1897, inplace=True)

# %%
training[(training['overall_qual'] == 9)  & (training['saleprice']>500000)]
training.drop([81, 151, 1671, 1692, 1796, 1964], inplace=True)

# %%
plt.scatter(training['all_flr_sf'], training['saleprice']);
training = training[training['all_flr_sf']<3000]

# %%
plt.scatter(training['garage_cars'], training['saleprice']);

# %%
training[training['garage_cars'] ==5]
training.drop(925, inplace=True)

# %%
plt.scatter(training['garage_area'], training['saleprice']);
training['garage_area'] = training['garage_area'].apply(lambda x: training['garage_area'].mean() if x == 0 else x)
training = training[training['garage_area']< 1200]

# %%
plt.scatter(training['garage_area'], training['saleprice']);

# %%
plt.scatter(training['garage_ratio'], training['saleprice']);
training[training['garage_ratio'] > .0065]
training.drop([554, 873, 1861, 2026], inplace=True)

# %%
plt.scatter(training['mas_vnr_area'], training['saleprice']);
training['mas_vnr_area'] = training['mas_vnr_area'].apply(lambda x: training['mas_vnr_area'].mean() if x == 0 else x)

# %%
training = training[training['mas_vnr_area']< 1400]
plt.scatter(training['mas_vnr_area'], training['saleprice']);

# %%
plt.scatter(training['total_bath'], training['saleprice']);
training[training['total_bath']>=5]
training.drop([791, 1325, 1566, 1584, 1605], inplace=True)

# %%
plt.scatter(training['total_bsmt_sf'], training['saleprice']);
training['total_bsmt_sf'] = training['total_bsmt_sf'].apply(lambda x: training['total_bsmt_sf'].mean() if x == 0 else x)
training[(training['total_bsmt_sf'] > 3000) & (training['saleprice'] < 400000)]
training.drop(1147, inplace=True)

# %%
plt.scatter(training['totrms_abvgrd'], training['saleprice']);
training = training[training['totrms_abvgrd'] < 13]

# %%
plt.scatter(training['year_built'], training['saleprice']);
training[(training['year_built']<1900) & (training['saleprice']>300000)]
training.drop(1141, inplace=True)

# %%
plt.scatter(training['year_remod/add'], training['saleprice']);
training['year_remod/add'] = training['year_remod/add'].apply(lambda x: training['year_remod/add'].median() if x == 0 else x)

# %%
training.to_csv('./datasets/training_enhanced.csv')
test.to_csv('./datasets/test_enhanced.csv')
